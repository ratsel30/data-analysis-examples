# %%
import pandas as pd

# %%
df = pd.read_csv('data/minjust2018.csv', 
                 header=None, 
                 usecols=[4, 9, 27, 28, 33])
df.rename(columns={4:"name", 9:"tel", 27:"director", 28:"activity", 33:"founder"}, 
         inplace=True)
df
# Out:
#                                                      name              tel  \
# 0       Коммерческий кооператив "Семеноводческий произ...    96346-3302-КК
# 1                                       ОО "Кайберен эне"     4220-3300-ОО
# 2       Общество с ограниченной ответственностью "Дете...   96342-3302-ООО
# 3                  Иностранное Казахское ОсОО "Валькирия"    4199-3300-ООО
# 4                                          ОсОО "Harour''   81897-3308-ООО
# 5       Государственное предприятие "Иссык-кульское ры...    96344-3302-ГП
# 6                        ОсОО Редакция газеты " Эл созу "    4079-3301-ООО
# 7            РО "Церковь Евангельских христиан-баптистов"     4011-3301-РО
# 8         Общество с ограниченной ответственностью "Вояж"   75352-3310-ООО
# 9             РО "Церковь Евангельских Христян-баптистов"    81919-3308-РО
# 10      Общество с ограниченной ответственностью "Мана...   75357-3310-ООО
# ...

# %%
df.fillna('', inplace=True)

# %%
df.loc[:10, ["name", "founder"]]
# Out:
#                                                  name  \
# 0   Коммерческий кооператив "Семеноводческий произ...
# 1                                   ОО "Кайберен эне"
# 2   Общество с ограниченной ответственностью "Дете...
# 3              Иностранное Казахское ОсОО "Валькирия"
# 4                                      ОсОО "Harour''
# 5   Государственное предприятие "Иссык-кульское ры...
# 6                    ОсОО Редакция газеты " Эл созу "
# 7        РО "Церковь Евангельских христиан-баптистов"
# 8     Общество с ограниченной ответственностью "Вояж"
# 9         РО "Церковь Евангельских Христян-баптистов"
# 10  Общество с ограниченной ответственностью "Мана...
#
#                                               founder
# 0   Замените на физическое лицо 1, Замените на физ...
# 1                               инициаторы 10 человек
# 2                      Жансеркеев аманат Базарканович
# 3                         Бражников Сергей Алексеевич
# ...

# %%
df
# Out:
#                                                      name              tel  \
# 0       Коммерческий кооператив "Семеноводческий произ...    96346-3302-КК
# 1                                       ОО "Кайберен эне"     4220-3300-ОО
# 2       Общество с ограниченной ответственностью "Дете...   96342-3302-ООО
# 3                  Иностранное Казахское ОсОО "Валькирия"    4199-3300-ООО
# 4                                          ОсОО "Harour''   81897-3308-ООО
# 5       Государственное предприятие "Иссык-кульское ры...    96344-3302-ГП
# 6                        ОсОО Редакция газеты " Эл созу "    4079-3301-ООО
# 7            РО "Церковь Евангельских христиан-баптистов"     4011-3301-РО
# 8         Общество с ограниченной ответственностью "Вояж"   75352-3310-ООО
# 9             РО "Церковь Евангельских Христян-баптистов"    81919-3308-РО
# 10      Общество с ограниченной ответственностью "Мана...   75357-3310-ООО
# ...

# %%
#выбрать ряды с 389 по 5678
df.loc[389:5678]
# Out:
#                                                    name              tel  \
# 389   Общественное объединение "Бишкекский центр пси...     3229-3301-ОО
# 390   Общественный фонд "Благотворительный обществен...    96322-3302-ОФ
# 391   АО закрытого типа " УРАН " (находится в процес...
# 392                                 ОсОО " КЫЗЫЛ-КАРА "    3794-3301-ООО
# 393   Управление внебюджетной деятельности Министерс...    3682-3301-У-е
# 394   Ошское представительство Фонд Развития сельско...   75529-3310-П-о
# 395        Обшественный Благотворительный фонд " НИЕТ "     3631-3301-ОФ
# 396                                    ООО "БАЙТИК-ТУР"   82566-3308-ООО
# 397   ООО  Научно-производственное  объединение  " С...    3664-3301-ООО
# 398                                      ОсОО " ШАБАН "   82559-3308-ООО
# 399   Некоммерческая организация жилищно-строительны...     3776-3301-НК
# 400   Объединение работодателей"Ассоциация содействи...    47455-3303-ОР
# ...

# %%
# колонки name founder

# %%
#выбрать ряды 1,2,58,76
df.loc[[1, 2, 58, 76]]
# Out:
#                                                  name             tel  \
# 1                                   ОО "Кайберен эне"    4220-3300-ОО
# 2   Общество с ограниченной ответственностью "Дете...  96342-3302-ООО
# 58       РО "Церковь Евангельских христиан-баптистов"   81904-3308-РО
# 76     Иностранное Турецкое ООО "Turk Elektro Ternir"   4049-3300-ООО
#
#                           director  \
# 1      Омурбеков Алмаз Ороскулович
# 2   Жансеркеев аманат Базарканович
# 58          Лунёв Борис Савельевич
# 76                   Зекерия Балык
#
#                                             activity  \
# 1
# 2   Обеспечение общественного порядка и безопасности
# 58
# 76
#
#                             founder
# 1             инициаторы 10 человек
# 2    Жансеркеев аманат Базарканович
# 58  инициаторы по списку 10-человек
# 76        екерия Балык, Фантих Турк

# %%
#0-15
df.loc[:15]
# Out:
#                                                  name             tel  \
# 0   Коммерческий кооператив "Семеноводческий произ...   96346-3302-КК
# 1                                   ОО "Кайберен эне"    4220-3300-ОО
# 2   Общество с ограниченной ответственностью "Дете...  96342-3302-ООО
# 3              Иностранное Казахское ОсОО "Валькирия"   4199-3300-ООО
# 4                                      ОсОО "Harour''  81897-3308-ООО
# 5   Государственное предприятие "Иссык-кульское ры...   96344-3302-ГП
# 6                    ОсОО Редакция газеты " Эл созу "   4079-3301-ООО
# 7        РО "Церковь Евангельских христиан-баптистов"    4011-3301-РО
# 8     Общество с ограниченной ответственностью "Вояж"  75352-3310-ООО
# 9         РО "Церковь Евангельских Христян-баптистов"   81919-3308-РО
# 10  Общество с ограниченной ответственностью "Мана...  75357-3310-ООО
# 11  Совместное кыргызско-казахстанское общество с ...   4233-3300-ООО
# ...

# %%
#111110 :
df.loc[111110:]
# Out:
#                                                      name              tel  \
# 111110  Общество с ограниченной ответственностью "Акса...   79040-3304-ООО
# 111111  Общество с ограниченной ответственностью "Микр...   19418-3300-ООО
# 111112  Общество с ограниченной ответственностью "Хан ...  137827-3300-ООО
# 111113  Общество с ограниченной ответственностью "Лого...  136807-3308-ООО
# 111114  Сельскохозяйственный производственный кооперат...    79862-3304-НК
# 111115  Филиал Открытого акционерного общества "Россий...  114782-3300-Ф-л
# 111116   Общество с ограниченной ответственностью "Тулга"  119575-3301-ООО
# 111117  Общество с ограниченной ответственностью "Эйч ...  137826-3300-ООО
# 111118  Общество с ограниченной ответственностью "Техо...  135672-3309-ООО
# 111119  Общество с ограниченной ответственностью "Алан...  137847-3301-ООО
# 111120     Учреждение "Нарынский районный отдел культуры"   98608-3304-У-е
# ...

# %%
#повторить 1-4 для колокни activity
df.loc[11110: , "activity"]
# Out:
# 11110
# 11111
# 11112                                    Управление фондами
# 11113     Социальное обслуживание с обеспечением прожива...
# 11114     Предоставление услуг по обработке урожая сельс...
# 11115
# 11116                           Ремонт прочего оборудования
# 11117
# 11118     Производство прочих текстильных изделий, не вк...
# 11119      Деятельность грузового автомобильного транспорта
# 11120         Растениеводство в сочетании с животноводством
# 11121
# 11122         Растениеводство в сочетании с животноводством
# 11123     Предоставление услуг по обработке урожая сельс...
# 11124     Предоставление услуг по обработке урожая сельс...
# 11125                         Транспортная обработка грузов
# 11126     Деятельность прочих общественных организаций, ...
# 11127     Производство прочих текстильных изделий, не вк...
# 11128         Растениеводство в сочетании с животноводством
# 11129           Государственное управления общего характера
# ...

# %%
df.loc[:15 , ["name", "founder"]]
# Out:
#                                                  name  \
# 0   Коммерческий кооператив "Семеноводческий произ...
# 1                                   ОО "Кайберен эне"
# 2   Общество с ограниченной ответственностью "Дете...
# 3              Иностранное Казахское ОсОО "Валькирия"
# 4                                      ОсОО "Harour''
# 5   Государственное предприятие "Иссык-кульское ры...
# 6                    ОсОО Редакция газеты " Эл созу "
# 7        РО "Церковь Евангельских христиан-баптистов"
# 8     Общество с ограниченной ответственностью "Вояж"
# 9         РО "Церковь Евангельских Христян-баптистов"
# 10  Общество с ограниченной ответственностью "Мана...
# 11  Совместное кыргызско-казахстанское общество с ...
# 12             Производственный кооператив "Кожешкен"
# 13           Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14       Южное отделение Национального агенства связи
# 15  Общество с ограниченной ответственностью "Жолб...
#
# ...

# %%
df.loc[[1, 2, 58, 76], "name": "activity"]
# Out:
#                                                  name             tel  \
# 1                                   ОО "Кайберен эне"    4220-3300-ОО
# 2   Общество с ограниченной ответственностью "Дете...  96342-3302-ООО
# 58       РО "Церковь Евангельских христиан-баптистов"   81904-3308-РО
# 76     Иностранное Турецкое ООО "Turk Elektro Ternir"   4049-3300-ООО
#
#                           director  \
# 1      Омурбеков Алмаз Ороскулович
# 2   Жансеркеев аманат Базарканович
# 58          Лунёв Борис Савельевич
# 76                   Зекерия Балык
#
#                                             activity
# 1
# 2   Обеспечение общественного порядка и безопасности
# 58
# 76

# %%
df.loc[df['director']== df['founder']]
# Out:
#                                                      name              tel  \
# 2       Общество с ограниченной ответственностью "Дете...   96342-3302-ООО
# 3                  Иностранное Казахское ОсОО "Валькирия"    4199-3300-ООО
# 8         Общество с ограниченной ответственностью "Вояж"   75352-3310-ООО
# 10      Общество с ограниченной ответственностью "Мана...   75357-3310-ООО
# 15      Общество с ограниченной ответственностью "Жолб...   75307-3310-ООО
# 24      Общество с ограниченной ответственностью "КМ-С...   47632-3303-ООО
# 27         Общество с ограниченной ответственностью "Шох"   47611-3303-ООО
# 29      Общество с ограниченной ответственностью "Чынгыз"   75320-3310-ООО
# 30                                         ООО "АЛМАЗ RT"   81937-3308-ООО
# 31      Общество с ограниченной ответственностью "Адил...   75323-3310-ООО
# 35       Общество с ограниченной ответственностью "Кунан"   75321-3310-ООО
# ...

# %%
#

# %%
df.loc[df['director'].str.contains('Аликбаева')]
# Out:
# Empty DataFrame
# Columns: [name, tel, director, activity, founder]
# Index: []

# %%
# найти
